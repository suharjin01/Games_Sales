# %% [markdown]
# <a href="https://colab.research.google.com/github/suharjin01/Games_Sales/blob/main/Games_Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Impoert Dataset

# %%
df = pd.read_csv('Games_Sales.csv')

df.head()
# Out:
#                             Name  Sales     Series    Release  \
# 0  PlayerUnknown's Battlegrounds   42.0        NaN  12/1/2017
# 1                      Minecraft   33.0  Minecraft  11/1/2011
# 2                     Diablo III   20.0     Diablo   5/1/2012
# 3                    Garry's Mod   20.0        NaN  11/1/2006
# 4                       Terraria   17.2        NaN   5/1/2011
#
#                  Genre               Developer               Publisher
# 0        Battle royale            PUBG Studios                 Krafton
# 1    Sandbox, survival          Mojang Studios          Mojang Studios
# 2  Action role-playing  Blizzard Entertainment  Blizzard Entertainment
# 3              Sandbox       Facepunch Studios                   Valve
# 4     Action-adventure                Re-Logic                Re-Logic

# %%
df.shape
# Out:
# (177, 7)

# %% [markdown]
# #Missing Value
# ##Menampilkan mengisi data yang mengandung NaN value

# %%
df.isnull()
# Out:
#       Name  Sales  Series  Release  Genre  Developer  Publisher
# 0    False  False    True    False  False      False      False
# 1    False  False   False    False  False      False      False
# 2    False  False   False    False  False      False      False
# 3    False  False    True    False  False      False      False
# 4    False  False    True    False  False      False      False
# ..     ...    ...     ...      ...    ...        ...        ...
# 172  False  False    True    False  False      False      False
# 173  False  False   False    False  False      False      False
# 174  False  False   False    False  False      False      False
# 175  False  False   False    False  False      False      False
# 176  False  False   False    False  False      False      False
#
# [177 rows x 7 columns]

# %%
df.isnull().any()
# Out:
# Name         False
# Sales        False
# Series        True
# Release      False
# Genre        False
# Developer    False
# Publisher    False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Name          0
# Sales         0
# Series       36
# Release       0
# Genre         0
# Developer     0
# Publisher     0
# dtype: int64

# %%
df['Series'].unique()
# Out:
# array([nan, 'Minecraft', 'Diablo', 'Warcraft', 'Half-Life', 'The Witcher',
#        'StarCraft', 'The Sims', 'RollerCoaster Tycoon', 'Civilization',
#        'Truck Simulator', 'Guild Wars', 'ARMA', 'The Last Ninja',
#        'SimCity', 'Populous', 'Warhammer', 'Carmen Sandiego',
#        'Dark Souls', 'Age of Empires', 'Command & Conquer', 'Crysis',
#        'EverQuest', 'Life Is Strange', 'Theme Park', 'Caesar',
#        'Lord of the Realm', 'Myst', 'Final Fantasy', '7 Days', 'Anno',
#        "Baldur's Gate", 'Battlefield', 'Black\xa0&\xa0White', 'Cossacks',
#        'Counter-Strike', 'Doom', 'Far Cry', 'Grand Theft Auto', 'Mafia',
#        'Neverwinter Nights', 'POD', 'Spore', 'Stronghold',
#        'Metal Gear Solid', 'Trucks Simulator', 'International Karate',
#        'Sega Mega Drive and Genesis Classics', 'Resident Evil',
#        'Street Fighter', 'Nier', 'Pac-Man', 'Alice',
#        'Ark: Survival Evolved', 'BioShock', 'Commandos', 'Crusader Kings',
# ...

# %%
pd.set_option('display.max_rows', None)
df['Series']
# Out:
# 0                                       NaN
# 1                                 Minecraft
# 2                                    Diablo
# 3                                       NaN
# 4                                       NaN
# 5                                  Warcraft
# 6                                 Half-Life
# 7                               The Witcher
# 8                                 StarCraft
# 9                                  The Sims
# 10                                      NaN
# 11                     RollerCoaster Tycoon
# 12                                Half-Life
# 13                                      NaN
# 14                             Civilization
# 15                                 The Sims
# 16                          Truck Simulator
# 17                               Guild Wars
# 18                                StarCraft
# 19                                 The Sims
# 20                                      NaN
# ...

# %% [markdown]
# ##Mengisi nilai NaN dengan "General"

# %%
df['Series'].fillna('General', inplace=True)

df.head()
# Out:
#                             Name  Sales     Series    Release  \
# 0  PlayerUnknown's Battlegrounds   42.0    General  12/1/2017
# 1                      Minecraft   33.0  Minecraft  11/1/2011
# 2                     Diablo III   20.0     Diablo   5/1/2012
# 3                    Garry's Mod   20.0    General  11/1/2006
# 4                       Terraria   17.2    General   5/1/2011
#
#                  Genre               Developer               Publisher
# 0        Battle royale            PUBG Studios                 Krafton
# 1    Sandbox, survival          Mojang Studios          Mojang Studios
# 2  Action role-playing  Blizzard Entertainment  Blizzard Entertainment
# 3              Sandbox       Facepunch Studios                   Valve
# 4     Action-adventure                Re-Logic                Re-Logic

# %%
df.columns
# Out:
# Index(['Name', 'Sales', 'Series', 'Release', 'Genre', 'Developer',
#        'Publisher'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       177 non-null    object
#  1   Sales      177 non-null    float64
#  2   Series     177 non-null    object
#  3   Release    177 non-null    object
#  4   Genre      177 non-null    object
#  5   Developer  177 non-null    object
#  6   Publisher  177 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 9.8+ KB

# %% [markdown]
# ##Mengganti tipe data Release menjadi tipe data DateTime

# %%
#mengganti tipe data kolom Release menjadi tipe data DateTime
df_cleaned = df.copy()

df_cleaned['Release'] = pd.to_datetime(df_cleaned['Release'])

print(df_cleaned.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       177 non-null    object
#  1   Sales      177 non-null    float64
#  2   Series     177 non-null    object
#  3   Release    177 non-null    datetime64[ns]
#  4   Genre      177 non-null    object
#  5   Developer  177 non-null    object
#  6   Publisher  177 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 9.8+ KB
# None

# %% [markdown]
# #EDA

# %% [markdown]
# ## - Mengetahu Game tertua dan Game terbaru

# %%
df_cleaned.sort_values(by='Release')
# Out:
#                                                   Name  Sales  \
# 133                                            Hydlide    1.0
# 34              Where in the World Is Carmen Sandiego?    4.0
# 88                                International Karate    1.5
# 162                                             Tetris    1.0
# 22                                        Last Ninja 2    5.5
# 151                                            RoboCop    1.0
# 30                                            Populous    4.0
# 150                                     Return to Zork    1.0
# 51                                                Myst    2.5
# 156                           Star Wars: Rebel Assault    1.0
# 67                                                Doom    2.0
# 68                              Doom II: Hell on Earth    2.0
# 173               Wing Commander 3: Heart of the Tiger    1.0
# 124                                      Full Throttle    1.0
# ...

# %%
df_cleaned.to_csv('games_sales_cleaned.csv', index=False)
